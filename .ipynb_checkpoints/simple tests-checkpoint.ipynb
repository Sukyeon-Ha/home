# %%
L = [1,2,3,4,5]

L[0:3]
len(L)
# Out:
# 5

# %%
L = [1,2,3,4,5]
for index, value in enumerate(L):
    print(index,value)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5

# %%
"122345".find("34")
# Out:
# 3

# %%
"12345".find("6")
# Out:
# -1
